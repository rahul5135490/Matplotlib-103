# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xpoints=np.array([1,20])
ypoints=np.array([10,200])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([13,20])
ypoints=np.array([10,200])
plt.plot(xpoints,ypoints,"+")
plt.show()

# %%
ypoints=np.array([10,20,90])
plt.plot(ypoints,"+""r")
plt.show()

# %%
ypoints=np.array([10,20,90])
plt.plot(ypoints,"*""r")
plt.show()

# %%
xpoints=np.array([10,9,10])
ypoints=np.array([1,20,9])
plt.plot(xpoints,ypoints,marker="*",ms=20,color="k")
plt.show()

# %%
xpoints=np.array([10,9,10])
ypoints=np.array([1,20,9])
plt.plot(xpoints,ypoints,marker="*",ms=20,color="k",mec="y")
plt.show()

# %%
xpoints=np.array([10,9,10])
ypoints=np.array([1,20,9])
plt.plot(xpoints,ypoints,marker="o",ms=20,color="k",mec="y",mfc="b")
plt.show()

# %%
xpoints=np.array([10,9,10])
ypoints=np.array([1,20,9])
plt.plot(xpoints,ypoints,marker="*",ms=20,color="k",mec="y",linewidth=5)
plt.show()

# %%
xpoints=np.array([10,9,10])
ypoints=np.array([1,20,9])
plt.plot(xpoints,ypoints,linestyle="dotted",ms=20,color="k",mec="y")
plt.show()

# %%
xpoints=np.array([10,9,10])
ypoints=np.array([1,20,9])
plt.plot(xpoints,ypoints,marker="*",ms=20,color="k",mec="y")
plt.show()

# %%
y1=np.array([10,9,10,6,23,6])
y2=np.array([1,20,9.8,7])
plt.plot(y1,marker="o",ms=20,color="k",mec="k")
plt.plot(y2,marker="*",ms=20,color="r",mec="y")
plt.show()

# %%
x=np.array([10,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.plot(y1,marker="o",ms=20,color="k",mec="k")
plt.plot(y2,marker="*",ms=20,color="r",mec="y")
plt.show()

# %%
x=np.array([10,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.plot(x,y)
plt.xlabel("Avg pulse", fontsize=10,color="red")
plt.ylabel("Calorie burnage", fontsize=10,color="green")
plt.title("Blood Sample")
plt.show()

# %%
x=np.array([10,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.plot(x,y)
plt.xlabel("Avg pulse", fontsize=10,color="red")
plt.ylabel("Calorie burnage", fontsize=10,color="green")
plt.title("Blood Sample")
plt.grid(color="green",linestyle="dotted")
plt.show()

# %%
x=np.array([1,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.plot(x,y,color="orange")
plt.xlabel("Avg pulse", fontsize=10,color="red",loc="right")
plt.ylabel("Calorie burnage", fontsize=10,color="green")
plt.title("Blood Sample")
plt.grid(color="green",linestyle="dotted")
plt.show()

# %%
x=np.array([1,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.plot(x,y,color="orange")
plt.xlabel("Avg pulse", fontsize=10,color="red",loc="right")
plt.ylabel("Calorie burnage", fontsize=10,color="green")
plt.title("Blood Sample")
plt.grid(axis="x")
plt.show()

# %%
x=np.array([1,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.plot(x,y,color="orange")
plt.xlabel("Avg pulse", fontsize=10,color="red",loc="right")
plt.ylabel("Calorie burnage", fontsize=10,color="green")
plt.title("Blood Sample")
plt.grid(color="green",linestyle="dotted",axis="y")
plt.show()

# %%
x=np.array([1,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([1,9,1,6,23,6])
y=np.array([1,2,2.8,7,4,6])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
x=np.array([1,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.subplot(2,2,1)
plt.plot(x,y)
x=np.array([1,9,1,6,23,6])
y=np.array([1,2,2.8,7,4,6])
plt.subplot(2,2,2)
plt.plot(x,y)
x=np.array([1,9,10,6,23,6])
y=np.array([1,20,9.8,7,0,6])
plt.subplot(2,2,3)
plt.plot(x,y)
x=np.array([1,0,1,6,23,6])
y=np.array([1,2,2.8,7,4,6])
plt.subplot(2,2,4)
plt.plot(x,y)

# %%
x=np.array([1,9,10,6,23,6])
y=np.array([1,20,9.8,7,4,6])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Sales")
x=np.array([1,9,1,6,23,6])
y=np.array([1,2,2.8,7,4,6])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("Income")
plt.suptitle("My shop")
# Out:
# Text(0.5, 0.98, 'My shop')
